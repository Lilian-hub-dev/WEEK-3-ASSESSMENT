# %%
# User Complaint System
def title():
    Title = 'User_Complaint_System'
    print(Title)
    runtime = 1
    print('Welcome to Our Complaint Management Platform, we value your feedback!')
    print('Proceed to drop your complain?')
    input = StringVar('Click YES to continue, NO to Cancel')

# Comlaint submission page
user_database= {}
user_complaints = {}


def log_in():
    if user_database:
        
        user_input = input("Please enter your login credentials: ")
        labels = ['User_name:','Password:']
    
    if  user_input in user_database.values():
                 print('Your account is verified!')
                 StringVar = prompt.StringVar( prompt="Please submit your complain here:")
                 labels = ['Full Name:', 'Gender:', 'Comment:'] 
                 print('Your response is submitted, thank you!')

    else: 
            print('===============================')
            print('Sign up?')


def Save():
	msg = conn.Add(fullname.get(), SpanGender.get(), comment.get(1.0, 'end'))
	fullname.delete(0, 'end')
	comment.delete(1.0, 'end')
	showinfo(title='Add Info', message=msg)

def ShowList():
    user_complaints = [Complain1, Complain2, ...]
    print(user_complaints)
    
def Submit():
    Submit.config(command=SaveData)
    

import requests

url = "https://google-translate1.p.rapidapi.com/language/translate/v2"

payload = "q=Hello%2C%20world!&target=es&source=en"
headers = {
    'content-type': "application/x-www-form-urlencoded",
    'accept-encoding': "application/gzip",
    'x-rapidapi-key': "870f6b625dmshf8e56af233fc91bp136c80jsn93c71c415fae",
    'x-rapidapi-host': "google-translate1.p.rapidapi.com"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)

import requests

url = "https://google-translate1.p.rapidapi.com/language/translate/v2/languages"

headers = {
    'accept-encoding': "application/gzip",
    'x-rapidapi-key': "870f6b625dmshf8e56af233fc91bp136c80jsn93c71c415fae",
    'x-rapidapi-host': "google-translate1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)

import requests

url = "https://google-translate1.p.rapidapi.com/language/translate/v2/detect"

payload = "q=English%20is%20hard%2C%20but%20detectably%20so"
headers = {
    'content-type': "application/x-www-form-urlencoded",
    'accept-encoding': "application/gzip",
    'x-rapidapi-key': "870f6b625dmshf8e56af233fc91bp136c80jsn93c71c415fae",
    'x-rapidapi-host': "google-translate1.p.rapidapi.com"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# {"data":{"translations":[{"translatedText":"¡Hola Mundo!"}]}}
# ...
